# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from IPython.display import Image

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15532, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 15532 (delta 51), reused 118 (delta 43), pack-reused 15393
# Receiving objects: 100% (15532/15532), 14.53 MiB | 26.81 MiB/s, done.
# Resolving deltas: 100% (10580/10580), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !ls
# Out:
# benchmarks.py	 data	     LICENSE	      requirements.txt	tutorial.ipynb
# CITATION.cff	 detect.py   models	      segment		utils
# classify	 export.py   README.md	      setup.cfg		val.py
# CONTRIBUTING.md  hubconf.py  README.zh-CN.md  train.py

# %%
# %cd ../
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data  yolov5

# %%
# !cd drive

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data  yolov5

# %%
# !cd drive

# %%
# %cd /content/drive/MyDrive/hackathon_cars
# Out:
# /content/drive/MyDrive/hackathon_cars

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15532, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 15532 (delta 51), reused 118 (delta 43), pack-reused 15393
# Receiving objects: 100% (15532/15532), 14.53 MiB | 4.37 MiB/s, done.
# Resolving deltas: 100% (10580/10580), done.
# Updating files: 100% (141/141), done.

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/hackathon_cars/yolov5

# %%
# !python train.py --img 415 --batch 16 --epochs 30 --data dataset.yaml --weights yolov5s.pt --cache
# Out:
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.9 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# %cd drive
# Out:
# /content/drive

# %%
# !ls
# Out:
# MyDrive  Shareddrives

# %%
# %cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %cd hackathon_cars
# Out:
# /content/drive/MyDrive/hackathon_cars

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/hackathon_cars/yolov5

# %%
# !python detect.py --source runs/test/b.jpg --weights runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=runs/test/b.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/drive/MyDrive/hackathon_cars/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/hackathon_cars/yolov5/runs/test/b.jpg: 640x640 (no detections), 428.2ms
# Speed: 3.5ms pre-process, 428.2ms inference, 0.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
Image(filename='runs/detect/exp3/c.jpg', width=416)

# %%
# !python detect.py --source runs/test/f.jpg --weights runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=runs/test/f.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/drive/MyDrive/hackathon_cars/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/hackathon_cars/yolov5/runs/test/f.jpg: 384x640 1 severe, 250.3ms
# Speed: 1.0ms pre-process, 250.3ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7

# %%
Image(filename='runs/detect/exp7/f.jpg', width=416)

# %%
# !python detect.py --source runs/test/g.jpg --weights runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=runs/test/g.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/drive/MyDrive/hackathon_cars/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/hackathon_cars/yolov5/runs/test/g.jpg: 448x640 1 moderate, 499.4ms
# Speed: 1.2ms pre-process, 499.4ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
# !python detect.py --source runs/test/h.jpg --weights runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=runs/test/h.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/drive/MyDrive/hackathon_cars/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-145-g94714fe Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/hackathon_cars/yolov5/detect.py", line 261, in <module>
#     main(opt)
#   File "/content/drive/MyDrive/hackathon_cars/yolov5/detect.py", line 256, in main
#     run(**vars(opt))
# ...

# %%
Image(filename='runs/detect/exp8/g.jpg', width=416)
